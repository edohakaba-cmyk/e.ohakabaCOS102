# %% [markdown]
# # SIMPLE INTEREST
# P=float(input("Enter the Principal:"))
# R=float(input("Enter Rate(%):"))
# T=float(input("Enter Time(years):"))
# A = P* (1+(R/100)* T)
# print(A)

# %% [markdown]
# # COMPOUND INTEREST
# P=float(input("Enter the principal:"))
# R=float(input("Enter the Rate(%):"))
# N=float(input("Enter the Number of times interest is compounded in a year:"))
# T=float(input("Enter Time(years):"))
# A = P* (1+R/N) ** (N*T)
# print(A)

# %% [markdown]
# # ANNUITY PLAN
# PMT=float(input("Enter the payment per period:"))
# R=float(input("Enter the rate(%):"))
# N=float(input("Enter the Number of times interest is compounded in a year:"))
# T=float(input("Enter Time(years):"))
# A= PMT * (((1+R/N) ** (N*T) -1) / (R/N))
# print(A)

# %% [markdown]
# # SIMPLE INTEREST FLOWCHART
# ![Simple Interest](simpleinterest.png)

# %% [markdown]
# # COMPOUND INTEREST FLOWCHART
# ![Compound Interest](COMPOUNDINTEREST.png)

# %% [markdown]
# # ANNUITY PLAN
# ![Annuity plan]("C:\Users\edoha\Downloads\e.ohakabaCOS102\WEEK-1\annualplan.png")
