# %%
import pandas as pd 
girls_data = {
    'Name':['Evelyn', 'jessica', 'Somto', 'Edith', 'Lisa', 'Madonna', 'Waje', 'Tola', 'Aisha', 'laffa'],
 'Age':[17,16,17,18,16,18,17,20,19,17],
 'Height':[5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5],
'Scores':[80,85,70,60,76,66,87,95,50,49]
}
dg = pd.DataFrame(girls_data)
print(dg)

# representation of data for boys
boys_data ={
 'Name': ['Chinedu', 'liam', 'Wale', 'Gbenga', 'Abiola', 'Kola', 'Kunle', 'George', 'Thomas', 'Wesly'],
  'Age':[19,16,18,17,20,19,16,18,17,19],
  'Height':[5.7,5.9,5.8,6.1,5.9,5.5,6.1,5.4,5.8,5.7],
 'Scores':[74,87,75,68,66,78,87,98,54,60]
}
db = pd.DataFrame(boys_data)
print(db)
# Out:
#       Name  Age  Height  Scores
# 0   Evelyn   17     5.5      80
# 1  jessica   16     6.0      85
# 2    Somto   17     5.4      70
# 3    Edith   18     5.9      60
# 4     Lisa   16     5.6      76
# 5  Madonna   18     5.5      66
# 6     Waje   17     6.1      87
# 7     Tola   20     6.0      95
# 8    Aisha   19     5.7      50
# 9    laffa   17     5.5      49
#       Name  Age  Height  Scores
# 0  Chinedu   19     5.7      74
# 1     liam   16     5.9      87
# 2     Wale   18     5.8      75
# 3   Gbenga   17     6.1      68
# 4   Abiola   20     5.9      66
# 5     Kola   19     5.5      78
# 6    Kunle   16     6.1      87
# 7   George   18     5.4      98
# 8   Thomas   17     5.8      54
# 9    Wesly   19     5.7      60

# %% [markdown]
# i.) algorithm
# Begin
# inputs tudent names,age,height, and scores
# compute the data for girls and boys
# compute boys and girls data together
# print and display the table heading: Name | Age | Height | Scores
# Stop
