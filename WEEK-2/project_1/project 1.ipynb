# %% [markdown]
# # Pseudocode for store checkout after purchase
# BEGIN
# INPUT Number_of_items
# FOR each item
# INPUT item_Price
# COMPUTE TOTAL_PRICE=total+item_Price
# DISPLAY Total_amount=TOTAL_PRICE
# DISPLAY Total_amount
# PRINT "CUSTOMER'S PAYMENT IS SUCCESSFUL"
# IF PAYMENT>=Total_amount
# display "change"
# ELSE
# DISPLAY "Insufficient payment"
# END

# %% [markdown]
# # flowchart for storecheckout after purchase
# ![store checkout after purchase flowchart.png](attachment:0af341a4-4c7b-47f3-85ed-565ab038aeaa.png)

# %% [markdown]
# # flowchart for my everyday routine
# ![morning routine flowchart.png](attachment:52ba299e-9e3f-4444-bc6b-29708cb78498.png)

# %% [markdown]
# BEGIN
# Display NAME1, NAME2 AS STRING
# Display AGE1, AGE2,Temp as interger
# Input NAME1
# INPUT AGE1
# INPUT NAME2
# INPUT AGE2
# Temp= AGE1
# AGE1=AGE2
# AGE2=Temp
# Display "swapping of AGE done"
# NAME1=AGE1
# NAME2=AGE2
