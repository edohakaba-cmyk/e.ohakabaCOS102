# %%
import pandas as pd

df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Insights
# 1.Gender was one of the strongest predictors of survival, with the vast majority of survivors being female.

# %% [markdown]
# ![insight 1.png](attachment:f4c8b094-f5b5-48e2-b81c-d8dc5b7e5cec.png)

# %% [markdown]
# 2.There was a strong correlation between class and survival. Passengers in 1st class had the highest survival rate, followed by 2nd class, while those in 3rd class had the lowest chance of surviving, likely due to their location on the ship and access to lifeboats
# While the majority of passengers were in their 20s and 30s, the visualization reveals a spike in survival among very young children. In contrast, the

# %% [markdown]
# ![insight 2.png](attachment:5bc41442-fd8b-4bbc-8ff8-f3b0b10470c3.png)

# %% [markdown]
# 3.Largest group of those who did not survive fell into the 18–40 age range.

# %% [markdown]
# ![insight 3.png](attachment:d07172d2-297e-46b9-940d-7254d1f9a874.png)
